# %% [markdown]
# <a href="https://colab.research.google.com/github/umakoduru2204/FMML-LAB-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 15:01:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   120MB/s    in 0.6s
#
# 2024-03-30 15:01:15 (120 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22484  1609.05057v2  Sparse subspace clustering (SSC) is an elegant...  stat
# 12417  1801.06720v1  In this paper, we study regression problems ov...  stat
# 4333    1410.3751v1  A reliable human skin detection method that is...    cs
# 22085   1410.7365v2  In high-dimensional data, structured noise cau...  stat
# 17125  1708.07690v1  The centroid-based model for extractive docume...    cs
# ...             ...                                                ...   ...
# 9380   1605.07604v1  Probabilistic modeling is cyclical: we specify...  stat
# 14253   1311.2694v2  Community detection in networks is a key explo...  stat
# 20565  1606.09140v3  A qualitative representation $\phi$ is like an...    cs
# 10760   1402.0282v1  This paper explores combinatorial optimization...    cs
# 33851  1711.04574v2  Artificial Neural Networks are powerful functi...    cs
#
#                                                    title  year  \
# 22484  Unbiased Sparse Subspace Clustering By Selecti...  2016
# 12417  Optimal Rates for Spectral-regularized Algorit...  2018
# 4333   A Fusion Approach for Efficient Human Skin Det...  2014
# 22085       Multiple Output Regression with Latent Noise  2014
# 17125  Revisiting the Centroid-based Method: A Strong...  2017
# ...                                                  ...   ...
# 9380                        Posterior Dispersion Indices  2016
# 14253  Hypothesis Testing for Automated Community Det...  2013
# 20565  Algebraic foundations for qualitative calculi ...  2016
# 10760  Principled Graph Matching Algorithms for Integ...  2014
# 33851         Learning Explanatory Rules from Noisy Data  2017
#
#                                                 keywords
# 22484  [clustering, unsupervised, segmentation, subsp...
# 12417  [regression, separable, parametric, regression...
# 4333   [detection, adaptable, different, conditions, ...
# 22085  [dimensional, structured, unobserved, affectin...
# 17125  [extractive, summarization, sentences, similar...
# ...                                                  ...
# 9380   [probabilistic, posterior, performance, evalua...
# 14253  [community, detection, exploratory, applicatio...
# 20565  [qualitative, representation, representation, ...
# 10760  [combinatorial, optimization, integrating, res...
# 33851  [artificial, approximators, modelling, solutio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22484    [clustering, unsupervised, segmentation, subsp...
# 12417    [regression, separable, parametric, regression...
# 4333     [detection, adaptable, different, conditions, ...
# 22085    [dimensional, structured, unobserved, affectin...
# 17125    [extractive, summarization, sentences, similar...
#                                ...
# 27734    [automatic, convolutional, segmentation, myoca...
# 7773     [interactions, canonical, representation, inte...
# 11639    [functional, resonance, increasing, available,...
# 7320     [detecting, distribution, distribution, distri...
# 22007    [performance, automatic, bandwidth, selectors,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8704 words.
# Out of those 4550 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe5d1165-ff42-40dd-87f3-2a876032f1fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe5d1165-ff42-40dd-87f3-2a876032f1fb")) {                    Plotly.newPlot(                        "fe5d1165-ff42-40dd-87f3-2a876032f1fb",                        [{"x":["segmentation","subspaces","unsupervised","condition","selective","guaranteed","assumption","investigated","algorithm","particular","separated","clustering","distributions","restrictions","regularized","investigate","considering","consequently","component","including","principal","hypothesis","parametric","generalize","attainable","algorithms","probability","theoretical","separable","convergence","regression","reproducing","computational","qualitative","robustness","knowledge","histogram","detection","quantitative","adaptable","variation","automatic","different","comparison","successfully","efficient","ethnicity","essential","effectiveness","conditions","illumination","solutions","macroeconomic","emphlatent","challenge","outperforms","important","explaining","prediction","structured","additionally","experiments","measurement","rotational","performance","structure","shrinkage","dimensional","correlated","unobserved","encouraging","introduce","expression","assumptions","therefore","affecting","simulations","hyperparameter","paramount","unidentifiability","simultaneously","interesting","correlation","modelling","formulated","independent","variables","importance","summarization","selecting","sentences","summaries","furthermore","extractive","similarity","collections","constructing","revisiting","framework","supervision","attention","conditional","datapoints","synchronous","properties","injecting","comparable","difficult","independence","structural","mechanism","regularities","precision","recombination","recurrent","understand","determine","experimental","classification","engineering","objective","deviation","community","computation","challenging","sentiment","statements","extraction","diversity","conclusion","emotional","demonstrate","subjective","automated","developed","summarize","automatically","incorporate","minimization","efficiently","significantly","outperform","alternating","benchmark","parameters","formulations","relationship","multitask","formulation","regularization","leveraging","corresponding","classifiers","separately","undesired","approaches","intensity","artifacts","potentially","variational","expressions","processes","typically","counterparts","autoencoders","nonparametric","representations","hierarchy","hierarchical","estimation","parameter","inference","conjugate","applications","justification","stochastic","conditionally","divergence","generalizes","generality","understood","objectives","functions","differences","questions","challenges","conferences","proposition","statistical","segmented","evaluation","difficulties","assessment","advantages","fixations","experiment","published","incorporates","estimators","predictive"],"y":[190,12,138,41,20,38,68,39,784,275,15,145,115,11,34,138,57,34,88,259,32,38,40,49,3,609,182,180,14,102,121,5,294,65,96,368,22,331,77,6,61,183,787,144,72,410,3,67,207,128,27,147,0,1,172,257,322,24,231,126,72,567,26,1,908,353,3,179,37,5,20,313,41,59,137,13,45,8,5,1,109,75,63,48,39,112,132,76,28,46,72,14,170,3,142,22,46,3,542,45,165,95,2,7,217,4,93,159,40,74,115,8,73,4,125,71,72,369,509,55,155,12,78,144,261,46,15,132,43,13,13,554,31,84,185,19,163,62,52,156,266,115,25,210,225,20,79,9,70,60,41,116,117,28,6,405,33,17,42,57,42,105,109,14,33,19,230,28,107,208,119,216,7,452,10,123,3,18,35,12,29,29,215,51,61,140,5,7,156,23,247,30,41,67,5,86,41,37,16,53],"type":"bar"},{"x":["segmentation","subspaces","unsupervised","condition","selective","guar ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4550,), (4550, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8208333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.4983498349834984);'>Architecture</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generating</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Descriptions</span> <span style=''>from</span> <span style=''>Source</span> <span style=''>Code</span> <span style=''>Changes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>model</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3360655737704918);'>automatically</span> <span style=''>describe</span> <span style=''>changes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>the</span> <span style=''>source</span> <span style=''>code</span> <span style=''>of</span> <span style=''>a</span> <span style=''>program</span> <span style=''>using</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>receives</span> <span style=''>as</span> <span style=''>input</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>code</span> <span style=''>commits</span> <span style=''>which</span> <span style=''>contains</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modifications</span> <span style=''>and</span> <span style=''>message</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>an</span> <span style=''>user</span> <span style=''>These</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.6326530612244898);'>modalities</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>train</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>decoder</span> <span style='background-color:rgba(0, 255, 0, 0.4983498349834984);'>architecture</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.4033149171270719);'>evaluated</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>on</span> <span style=''>twelve</span> <span style=''>real</span> <span style=''>world</span> <span style=''>open</span> <span style=''>source</span> <span style=''>projects</span> <span style=''>from</span> <span style=''>four</span> <span style='background-color:rgba(0, 255, 0, 0.348757497857755);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.4224598930481284);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.9223300970873787);'>languages</span> <span style='background-color:rgba(0, 255, 0, 0.4807692307692307);'>Quantitative</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6455696202531646);'>qualitative</span> <span style=''>results</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>generate</span> <span style=''>feasible</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>semantically</span> <span style=''>sound</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>descriptions</span> <span style=''>not</span> <span style=''>only</span> <span style=''>in</span> <span style=''>standard</span> <span style=''>in</span> <span style=''>project</span> <span style=''>settings</span> <span style=''>but</span> <span style=''>also</span> <span style=''>in</span> <span style=''>a</span> <span style=''>cross</span> <span style=''>project</span> <span style=''>setting</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Mutually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style=''>Hadamard</span> <span style=''>Kernel</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Modelling</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Couplings</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>kernel</span> <span style=''>that</span> <span style=''>models</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>couplings</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>The</span> <span style=''>pairwise</span> <span style=''>joint</span> <span style=''>kernel</span> <span style=''>measures</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>along</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>in</span> <span style=''>a</span> <span style=''>mutually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>fashion</span> <span style=''>A</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(LCGP)</span> <span style=''>model</span> <span style=''>combines</span> <span style=''>these</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>into</span> <span style=''>multiple</span> <span style=''>outputs</span> <span style=''>by</span> <span style=''>an</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>mixing</span> <span style=''>matrix</span> <span style=''>Probit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>support</span> <span style=''>for</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>sets</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>Results</span> <span style=''>on</span> <span style=''>several</span> <span style=''>datasets</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>the</span> <span style=''>LCGP</span> <span style=''>model</span> <span style=''>can</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>latent</span> <span style=''>signals</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieving</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>highlight</span> <span style=''>the</span> <span style=''>latent</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style=''>Labeling</span> <span style=''>Based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3095238095238095);'>Graphical</span> <span style=''>Models</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058824);'>Wasserstein</span> <span style=''>Messages</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Geometric</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>Assignment</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>Maximum</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Posteriori</span> <span style='background-color:rgba(255, 0, 0, 0.3121019108280255);'>inference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3095238095238095);'>graphical</span> <span style=''>models</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>utilizing</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058824);'>Wasserstein</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distances</span> <span style=''>for</span> <span style=''>coupling</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>assignment</span> <span style=''>measures</span> <span style=''>across</span> <span style=''>edges</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>a</span> <span style=''>given</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>is</span> <span style=''>smoothly</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>approximated</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>assignment</span> <span style=''>manifold</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style=''>update</span> <span style=''>scheme</span> <span style=''>combines</span> <span style=''>in</span> <span style=''>a</span> <span style=''>single</span> <span style=''>process</span> <span style=''>(i)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>integration</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>gradient</span> <span style=''>flow</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>rounding</span> <span style=''>to</span> <span style=''>integral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represent</span> <span style=''>valid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>labelings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Throughout</span> <span style=''>this</span> <span style=''>process</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>marginalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>known</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Manifold</span> <span style=''>Matching</span> <span style=''>using</span> <span style=''>Shortest</span> <span style=''>Path</span> <span style=''>Distance</span> <span style=''>and</span> <span style=''>Joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Neighborhood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style=''>Matching</span> <span style=''>datasets</span> <span style=''>of</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modalities</span> <span style=''>has</span> <span style=''>become</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>task</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>Existing</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>of</span> <span style=''>each</span> <span style=''>single</span> <span style=''>modality</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspondence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>which</span> <span style=''>often</span> <span style=''>results</span> <span style=''>in</span> <span style=''>sub</span> <span style=''>optimal</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>manifold</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>and</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>built</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modalities</span> <span style=''>Then</span> <span style=''>the</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>within</span> <span style=''>each</span> <span style=''>modality</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>from</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>graph</span> <span style=''>followed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>into</span> <span style=''>and</span> <span style=''>matching</span> <span style=''>in</span> <span style=''>a</span> <span style=''>common</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13216332378223497)
# 	processing (0.1010028653295129)
# 	segmentation (0.0680515759312321)
# 	knowledge (0.1318051575931232)
# 	detection (0.11855300859598854)
# 	representation (0.1421919770773639)
# 	information (0.2593123209169054)
# 	recognition (0.12320916905444126)
# 	different (0.2818767908309456)
# 	convolutional (0.13861031518624642)
#
# Some Statistics words are:
# 	statistical (0.14342629482071714)
# 	stochastic (0.1349601593625498)
# 	theoretical (0.15587649402390438)
# 	variables (0.14292828685258965)
# 	estimation (0.17629482071713148)
# 	distribution (0.18625498007968128)
# 	algorithm (0.39193227091633465)
# 	dimensional (0.18774900398406374)
# 	inference (0.2051792828685259)
# 	regression (0.17430278884462153)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c2b622c-d705-4c25-9c38-7e8850132984" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c2b622c-d705-4c25-9c38-7e8850132984")) {                    Plotly.newPlot(                        "5c2b622c-d705-4c25-9c38-7e8850132984",                        [{"x":["segmentation","subspaces","unsupervised","condition","selective","guaranteed","assumption","investigated","algorithm","particular","separated","clustering","distributions","restrictions","regularized","investigate","considering","consequently","component","including","principal","hypothesis","parametric","generalize","attainable","algorithms","probability","theoretical","separable","convergence","regression","reproducing","computational","qualitative","robustness","knowledge","histogram","detection","quantitative","adaptable","variation","automatic","different","comparison","successfully","efficient","ethnicity","essential","effectiveness","conditions","illumination","solutions","macroeconomic","emphlatent","challenge","outperforms","important","explaining","prediction","structured","additionally","experiments","measurement","rotational","performance","structure","shrinkage","dimensional","correlated","unobserved","encouraging","introduce","expression","assumptions","therefore","affecting","simulations","hyperparameter","paramount","unidentifiability","simultaneously","interesting","correlation","modelling","formulated","independent","variables","importance","summarization","selecting","sentences","summaries","furthermore","extractive","similarity","collections","constructing","revisiting","framework","supervision","attention","conditional","datapoints","synchronous","properties","injecting","comparable","difficult","independence","structural","mechanism","regularities","precision","recombination","recurrent","understand","determine","experimental","classification","engineering","objective","deviation","community","computation","challenging","sentiment","statements","extraction","diversity","conclusion","emotional","demonstrate","subjective","automated","developed","summarize","automatically","incorporate","minimization","efficiently","significantly","outperform","alternating","benchmark","parameters","formulations","relationship","multitask","formulation","regularization","leveraging","corresponding","classifiers","separately","undesired","approaches","intensity","artifacts","potentially","variational","expressions","processes","typically","counterparts","autoencoders","nonparametric","representations","hierarchy","hierarchical","estimation","parameter","inference","conjugate","applications","justification","stochastic","conditionally","divergence","generalizes","generality","understood","objectives","functions","differences","questions","challenges","conferences","proposition","statistical","segmented","evaluation","difficulties","assessment","advantages","fixations","experiment","published","incorporates","estimators","predictive","streaming","satisfaction","literature","interruption","engagement","naturally","covariates","efficiency","continuously","recommendation","guarantees","nontrivial","predicting","illustrated","popularity","considered","simulation","increasing","ensembles","extension","predictors","dependencies","influence","conditioning","arbitrary","consistent","dependence","inaccurate","financial","laboratory","scalability","screening","operational","optimized","reduction","coefficients","eliminating","seamlessly","massachusetts","restricting","collaboration","technique","constraints","widespread","beforehand","candidate","webquestions","classifier","implement","sequential","outperforming","convolutional","advantage","localization","proposals","conditio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	macroeconomic
# 	lindenstrauss
# 	announced
# 	validator
# 	unsatisfying
# 	statisticians
# 	robustification
# 	synchronization
# 	univariate
# 	integrands
# 	quadrature
# 	missforest
# 	detectability
# 	datastreams
# 	perceptible
# 	bonferroni
# 	homoscedastic
# 	heteroscedasticity
# 	heteroscedastic
# 	therapeutic
# Some words which never appear in Statistics papers:
# 	adaptable
# 	ethnicity
# 	extractive
# 	recombination
# 	conferences
# 	proposition
# 	fixations
# 	webquestions
# 	attentions
# 	converter
# 	argumentation
# 	attending
# 	monocular
# 	threefold
# 	repetitive
# 	advancements
# 	desiderata
# 	inheritance
# 	indifference
# 	deductive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
